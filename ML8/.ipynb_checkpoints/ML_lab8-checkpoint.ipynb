// %%
:dep smartcore = { version = "0.3.2", features = ["ndarray-bindings", "serde"] }
:dep bincode = "1.3"
:dep csv = "1.1"
:dep ndarray = { version = "0.15", features = ["rayon"] }
:dep linfa = { version = "0.7" }
:dep rand = "0.8"
:dep rand_chacha = "0.3"
:dep plotters = "0.3"
:dep linfa-preprocessing = "0.7"
:dep linfa-elasticnet = { version = "0.7"}
:dep polars = { version = "0.53", features = ["ndarray"] }
:dep polars-core = "0.53"
:dep linfa-reduction = "0.7"
:dep image = "0.24"
:opt 3
// Out:
// Optimization: 3

// %%
use linfa::prelude::*;
use linfa_reduction::Pca;
use plotters::prelude::*;
use ndarray::Array2;
use std::path::Path as StdPath;
use linfa_preprocessing::linear_scaling::LinearScaler;
use plotters::prelude::*;
use std::path::Path as StdPath;
use image::GenericImageView;
use polars_core::prelude::*;
use ndarray::Dim;
use ndarray::ArrayBase;
use ndarray::OwnedRepr;
use polars::prelude::CsvReadOptions;
use polars::prelude::SerReader;

// %%
let mut df = CsvReadOptions::default()
        .with_has_header(false)
        .try_into_reader_with_file_path(Some("FlagsData/flag.data".into())).unwrap()
        .finish().unwrap();
let color_cols = ["column_18", "column_29", "column_30"];
let mut color_map: std::collections::HashMap<String, f64> = std::collections::HashMap::new();
let mut counter = 0.0;
for col_name in color_cols {
    let series = df.column(col_name).unwrap().as_materialized_series();
    for val in series.iter() {
        let color_str = val.to_string().replace("\"", "");
        let _ = color_map.entry(color_str).or_insert_with(|| {
            let current = counter;
            counter += 1.0;
            current
        });
    }
}

for col_name in color_cols {
    let series = df.column(col_name).unwrap().as_materialized_series();
    let values: Vec<f64> = series.iter().map(|val| {
        let color_str = val.to_string().replace("\"", "");
        *color_map.get(&color_str).unwrap_or(&0.0)
    }).collect();
    let new_col = Series::new(col_name.into(), values);
    let _ = df.replace(col_name, new_col.into_column()).unwrap();
}
println!("Цвета: {:?}", color_map);
println!("Пример данных: \n{}", df.head(Some(5)));
// Out:
// Цвета: {"brown": 7.0, "white": 4.0, "blue": 2.0, "red": 1.0, "orange": 5.0, "green": 0.0, "gold": 3.0, "black": 6.0}
// Пример данных:
// shape: (5, 30)
// ┌─────────────┬──────────┬──────────┬──────────┬───┬───────────┬───────────┬───────────┬───────────┐
// │ column_1    ┆ column_2 ┆ column_3 ┆ column_4 ┆ … ┆ column_27 ┆ column_28 ┆ column_29 ┆ column_30 │
// │ ---         ┆ ---      ┆ ---      ┆ ---      ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---       │
// │ str         ┆ i64      ┆ i64      ┆ i64      ┆   ┆ i64       ┆ i64       ┆ f64       ┆ f64       │
// ╞═════════════╪══════════╪══════════╪══════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
// │ Afghanistan ┆ 5        ┆ 1        ┆ 648      ┆ … ┆ 0         ┆ 0         ┆ 6.0       ┆ 0.0       │
// │ Albania     ┆ 3        ┆ 1        ┆ 29       ┆ … ┆ 1         ┆ 0         ┆ 1.0       ┆ 1.0       │
// │ Algeria     ┆ 4        ┆ 1        ┆ 2388     ┆ … ┆ 0         ┆ 0         ┆ 0.0       ┆ 4.0       │
// ...

// %%
let feature_cols: Vec<String> = (2..=30).map(|i| format!("column_{}", i)).collect();
let dataset = Dataset::from(
    df.select(&feature_cols)
      .unwrap()
      .to_ndarray::<Float64Type>(IndexOrder::Fortran)
      .unwrap()
);
let scaler = LinearScaler::standard().fit(&dataset).expect("Scaling failed");
let dataset = scaler.transform(dataset);
println!("Dataset shape: {:?}", dataset.records().shape());
// let pca = Pca::params(2).fit(&dataset)?;
// let records = pca.predict(&dataset); // Возвращает Array2<f64>
// let root = BitMapBackend::new("flags_visual.png", (1200, 900)).into_drawing_area();
// root.fill(&WHITE)?;
// let mut chart = ChartBuilder::on(&root)
//     .caption("Flags PCA: Similarity Geometry", ("sans-serif", 40))
//     .margin(20)
//     .build_cartesian_2d(-5.0..5.0, -5.0..5.0)?;

// chart.configure_mesh().draw()?;
// let countries = df.column("column_1")?.as_materialized_series();
// for (i, row) in records.rows().into_iter().enumerate() {
//     let country_name = countries.get(i)?.to_string().replace("\"", "");
//     let img_path = format!("Flags/{}.png", country_name);
//     let x = row[0];
//     let y = row[1];
//     if StdPath::new(&img_path).exists() {
//         let img = image::open(&img_path)?;
//         let (w, h) = img.dimensions();
//         let aspect = w as f64 / h as f64; 
//         let scaled_img = image::imageops::resize(
//             &img, 40, (40.0 / aspect) as u32, 
//             image::imageops::FilterType::Triangle
//         );
//         let rgba_img = scaled_img.to_rgba8();        
//         // В Plotters 0.3 BitMapElement::new принимает 2 аргумента: точку и картинку
//         chart.draw_series(std::iter::once(
//             BitMapElement::new((x, y), rgba_img)
//         ))?;
//     } else {
//         chart.draw_series(std::iter::once(Circle::new((x, y), 4, RED.filled())))?;
//     }
// }
// root.present()?;
// Out:
// let dataset = Dataset::from(
// let dataset = Dataset::from(
//               ^^^^^^^ unsatisfied trait bound
// the trait bound `DatasetBase<ArrayBase<OwnedRepr<_>, Dim<[usize; 2]>>, ...>: From<...>` is not satisfied
// help: the trait `From<ndarray::ArrayBase<ndarray::data_repr::OwnedRepr<f64>, ndarray::dimension::dim::Dim<[usize; 2]>, f64>>` is not implemented for `DatasetBase<ArrayBase<OwnedRepr<_>, Dim<[usize; 2]>>, ArrayBase<OwnedRepr<_>, _>>`
// help: the following other types implement trait `From<T>`:
//   `DatasetBase<ArrayBase<D, Dim<[usize; 2]>>, ArrayBase<S, I>>` implements `From<(ArrayBase<D, Dim<[usize; 2]>>, ArrayBase<S, I>)>`
//   `DatasetBase<ArrayBase<D, I>, ArrayBase<OwnedRepr<()>, Dim<[usize; 1]>>>` implements `From<ArrayBase<D, I>>`
