// %%
:dep smartcore = { version = "0.3.2", features = ["ndarray-bindings", "serde"] }
:dep bincode = "1.3"
:dep csv = "1.1"
:dep ndarray = { version = "0.16", features = ["rayon"] }
:dep linfa = { version = "0.8.1" }
:dep rand = "0.8"
:dep rand_chacha = "0.3"
:dep plotters = "0.3"
:dep linfa-preprocessing =  "0.8.1" 
:dep linfa-elasticnet = { version =  "0.8.1" }
:dep polars = { version = "0.53", features = ["ndarray"] }
:dep polars-core = "0.53"
:dep linfa-reduction =  "0.8.1" 
:dep linfa-clustering="0.8.1"
:dep linfa-nn="0.8.1"
:dep image = "0.24"
:opt 3
// Out:
// Optimization: 3

// %%
use linfa::prelude::*;
use linfa_reduction::Pca;
use plotters::prelude::*;
use ndarray::Array2;
use std::path::Path as StdPath;
use linfa_preprocessing::linear_scaling::LinearScaler;
use plotters::prelude::*;
use std::path::Path as StdPath;
use image::GenericImageView;
use polars_core::prelude::*;
use ndarray::Dim;
use ndarray::ArrayBase;
use ndarray::OwnedRepr;
use polars::prelude::CsvReadOptions;
use polars::prelude::SerReader;
use linfa_clustering::{Dbscan,KMeans,Optics};
use rand::SeedableRng;
use rand_chacha::ChaCha8Rng;
use linfa_nn::distance::L2Dist;

// %%
let mut df = CsvReadOptions::default()
        .with_has_header(false)
        .try_into_reader_with_file_path(Some("FlagsData/flag.data".into())).unwrap()
        .finish().unwrap();
let color_cols = ["column_18", "column_29", "column_30"];
let mut color_map: std::collections::HashMap<String, f64> = std::collections::HashMap::new();
let mut counter = 0.0;
for col_name in color_cols {
    let series = df.column(col_name).unwrap().as_materialized_series();
    for val in series.iter() {
        let color_str = val.to_string().replace("\"", "");
        let _ = color_map.entry(color_str).or_insert_with(|| {
            let current = counter;
            counter += 1.0;
            current
        });
    }
}
for col_name in color_cols {
    let series = df.column(col_name).unwrap().as_materialized_series();
    let values: Vec<f64> = series.iter().map(|val| {
        let color_str = val.to_string().replace("\"", "");
        *color_map.get(&color_str).unwrap_or(&0.0)
    }).collect();
    let new_col = Series::new(col_name.into(), values);
    let _ = df.replace(col_name, new_col.into_column()).unwrap();
}
// Out:
// ()

// %%
let feature_cols: Vec<String> = (2..=30).map(|i| format!("column_{}", i)).collect();
let shape = (df.height(), feature_cols.len());
let x_vec: Vec<f64> = df.select(&feature_cols)
    .unwrap()
    .to_ndarray::<Float64Type>(IndexOrder::C)
    .unwrap()
    .into_iter()
    .collect();
let x_final = ndarray::Array2::from_shape_vec(shape, x_vec).unwrap();
let y_final = ndarray::Array1::from_iter(0..shape.0);
let dataset  = Dataset::new(x_final, y_final);
let scaler: LinearScaler<f64> = LinearScaler::standard().fit(&dataset).expect("errr");
let dataset = scaler.transform(dataset);
let pca: Pca<f64> = Pca::params(2).fit(&(dataset.clone())).unwrap();
let records = pca.predict(&(dataset.clone()));

// %%
let countries: Vec<String> = (df.column("column_1")).clone()
    .unwrap()
    .str()          
    .unwrap()
    .into_iter()     
    .map(|opt_val| opt_val.unwrap_or("unknown").to_string()) 
    .collect();
let root = BitMapBackend::new("pca_standart.png", (4000, 4000)).into_drawing_area();
root.fill(&WHITE).unwrap();
let mut chart = ChartBuilder::on(&root)
    .caption("PCA", ("sans-serif", 40))
    .margin(20)
    .build_cartesian_2d(-1000.0..1000.0, -1000.0..1000.0).unwrap();
chart.configure_mesh().draw().unwrap();
for id in 0..countries.len(){
    for entry in std::fs::read_dir("Flags/").unwrap(){
        let file = entry.unwrap();
        let name = file.file_name().to_string_lossy().into_owned();
        if name.contains(&countries[id]){
            let img = image::open(file.path()).unwrap();
            let (width, height) = img.dimensions();
            let row = records.row(id);
            let rgb_img = img.to_rgb8();
            let plt_img = BitMapElement::<(f64, f64), plotters::backend::RGBPixel>::with_ref(
                (row[0]*100.0, row[1]*100.0),
                rgb_img.dimensions(),
                rgb_img.as_raw()
            ).expect("pepes");
            
            chart.draw_series(std::iter::once(plt_img)).unwrap();
            break;
        }
    }
}
root.present().unwrap();
let img = image::open("pca_standart.png").expect("nfs");
let scaled = img.resize(1000, 1000, image::imageops::FilterType::Lanczos3);
scaled.save("pca_standart.png").expect("peps");

// %%
let pca: Pca<f64> = Pca::params(2).whiten(true).fit(&(dataset.clone())).unwrap();
let records = pca.predict(&(dataset.clone()));
let records_dataset = Dataset::from(records.clone());
let mut rng = ChaCha8Rng::seed_from_u64(42); 
let n_clusters = 3;
let kmeans_model:KMeans<f64, L2Dist> = KMeans::params(n_clusters)
    .fit(&records_dataset)
    .expect("kmeans errr");
let kmeans_labels = kmeans_model.predict(&records_dataset);
let countries: Vec<String> = df.column("column_1").clone()
    .unwrap()
    .str()          
    .unwrap()
    .into_iter()     
    .map(|opt_val| opt_val.unwrap_or("unknown").to_string()) 
    .collect();
let root = BitMapBackend::new("kmeans_3.png", (4000, 4000)).into_drawing_area();
root.fill(&WHITE).unwrap();
let mut chart = ChartBuilder::on(&root)
    .caption("Kmeans_3", ("sans-serif", 40))
    .margin(20)
    .build_cartesian_2d(-1000.0..1000.0, -1000.0..1000.0).unwrap();
chart.configure_mesh().draw().unwrap();
use std::f64::consts::PI;


let radius = 350.0; 

for id in 0..countries.len(){
    for entry in std::fs::read_dir("Flags/").unwrap(){
        let file = entry.unwrap();
        let name = file.file_name().to_string_lossy().into_owned();
        if name.contains(&countries[id]){
            let img = image::open(file.path()).unwrap();
            let (width, height) = img.dimensions();
            let row = records.row(id);
            let rgb_img = img.to_rgb8();
            let cluster_id = kmeans_labels[id]; 
            let angle = (cluster_id as f64) * (2.0 * PI / n_clusters as f64);
            let offset_x = angle.cos() * radius;
            let offset_y = angle.sin() * radius;
            let pose = (row[0] * 100.0 + offset_x, row[1] * 100.0 + offset_y);
            let plt_img = BitMapElement::<(f64, f64), plotters::backend::RGBPixel>::with_ref(
                pose,
                rgb_img.dimensions(),
                rgb_img.as_raw()
            ).expect("pepes");
            
            chart.draw_series(std::iter::once(plt_img)).unwrap();
            break;
        }
    }
}
root.present().unwrap();
let img = image::open("kmeans_3.png").expect("nfs");
let scaled = img.resize(1000, 1000, image::imageops::FilterType::Lanczos3);
scaled.save("kmeans_3.png").expect("peps");

// %%
let pca: Pca<f64> = Pca::params(2).whiten(true).fit(&(dataset.clone())).unwrap();
let records = pca.predict(&(dataset.clone()));
let records_dataset = Dataset::from(records.clone());
let mut rng = ChaCha8Rng::seed_from_u64(42); 
let n_clusters = 6;
let kmeans_model:KMeans<f64, L2Dist> = KMeans::params(n_clusters)
    .fit(&records_dataset)
    .expect("kmeans errr");
let kmeans_labels = kmeans_model.predict(&records_dataset);
let countries: Vec<String> = df.column("column_1").clone()
    .unwrap()
    .str()          
    .unwrap()
    .into_iter()     
    .map(|opt_val| opt_val.unwrap_or("unknown").to_string()) 
    .collect();
let root = BitMapBackend::new("kmeans_6.png", (4000, 4000)).into_drawing_area();
root.fill(&WHITE).unwrap();
let mut chart = ChartBuilder::on(&root)
    .caption("Kmeans_6", ("sans-serif", 40))
    .margin(20)
    .build_cartesian_2d(-1000.0..1000.0, -1000.0..1000.0).unwrap();
chart.configure_mesh().draw().unwrap();
use std::f64::consts::PI;


let radius = 350.0; 

for id in 0..countries.len(){
    for entry in std::fs::read_dir("Flags/").unwrap(){
        let file = entry.unwrap();
        let name = file.file_name().to_string_lossy().into_owned();
        if name.contains(&countries[id]){
            let img = image::open(file.path()).unwrap();
            let (width, height) = img.dimensions();
            let row = records.row(id);
            let rgb_img = img.to_rgb8();
            let cluster_id = kmeans_labels[id]; 
            let angle = (cluster_id as f64) * (2.0 * PI / n_clusters as f64);
            let offset_x = angle.cos() * radius;
            let offset_y = angle.sin() * radius;
            let pose = (row[0] * 100.0 + offset_x, row[1] * 100.0 + offset_y);
            let plt_img = BitMapElement::<(f64, f64), plotters::backend::RGBPixel>::with_ref(
                pose,
                rgb_img.dimensions(),
                rgb_img.as_raw()
            ).expect("pepes");
            
            chart.draw_series(std::iter::once(plt_img)).unwrap();
            break;
        }
    }
}
root.present().unwrap();
let img = image::open("kmeans_6.png").expect("nfs");
let scaled = img.resize(1000, 1000, image::imageops::FilterType::Lanczos3);
scaled.save("kmeans_6.png").expect("peps");

// %%
use linfa::traits::Transformer;
let pca: Pca<f64> = Pca::params(2).whiten(true).fit(&(dataset.clone())).unwrap();
let records = pca.predict(&(dataset.clone()));
let records_dataset = Dataset::from(records.clone());
let mut rng = ChaCha8Rng::seed_from_u64(42); 
let min_points = 2;
let clusters = Dbscan::params(min_points)
    .tolerance(0.15)
    .transform(&records)
    .unwrap();
let countries: Vec<String> = df.column("column_1").clone()
    .unwrap()
    .str()          
    .unwrap()
    .into_iter()     
    .map(|opt_val| opt_val.unwrap_or("unknown").to_string()) 
    .collect();
let root = BitMapBackend::new("dbscan_2.png", (4000, 4000)).into_drawing_area();
root.fill(&WHITE).unwrap();
let mut chart = ChartBuilder::on(&root)
    .caption("Dbscan_2", ("sans-serif", 40))
    .margin(20)
    .build_cartesian_2d(-1000.0..1000.0, -1000.0..1000.0).unwrap();
chart.configure_mesh().draw().unwrap();
use std::f64::consts::PI;
let radius = 350.0;
let mut n_clusters=10;
for id in 0..countries.len(){
    for entry in std::fs::read_dir("Flags/").unwrap(){
        let file = entry.unwrap();
        let name = file.file_name().to_string_lossy().into_owned();
        if name.contains(&countries[id]){
            let img = image::open(file.path()).unwrap();
            let (width, height) = img.dimensions();
            let row = records.row(id);
            let rgb_img = img.to_rgb8();
            let mut real_id =0;
            let cluster_id=clusters[id];
            match cluster_id {
            Some(cid) => {
                real_id=cid;
            },
            None => {
                    real_id=20;
                }
            }
            let angle = (real_id as f64) * (2.0 * PI / n_clusters as f64);
            let offset_x = angle.cos() * radius;
            let offset_y = angle.sin() * radius;
            let pose = (row[0] * 100.0 + offset_x, row[1] * 100.0 + offset_y);
            let plt_img = BitMapElement::<(f64, f64), plotters::backend::RGBPixel>::with_ref(
                pose,
                rgb_img.dimensions(),
                rgb_img.as_raw()
            ).expect("pepes");
            
            chart.draw_series(std::iter::once(plt_img)).unwrap();
            break;
        }
    }
}
root.present().unwrap();
let img = image::open("dbscan_2.png").expect("nfs");
let scaled = img.resize(1000, 1000, image::imageops::FilterType::Lanczos3);
scaled.save("dbscan_2.png").expect("peps");

// %%
use linfa::traits::Transformer;
use linfa_clustering::GaussianMixtureModel;
let pca: Pca<f64> = Pca::params(2).whiten(true).fit(&(dataset.clone())).unwrap();
let records = pca.predict(&(dataset.clone()));
let records_dataset = Dataset::from(records.clone());
let mut rng = ChaCha8Rng::seed_from_u64(42); 
let n_clusters = 6;
let gmm:GaussianMixtureModel<f64> = GaussianMixtureModel::params(n_clusters)
            .n_runs(25)
            .tolerance(1e-4)
            .with_rng(rng)
            .fit(&records_dataset).unwrap();
let clusters:linfa::DatasetBase<ndarray::Array2<f64>, ndarray::Array1<usize>> = gmm.predict(records_dataset);
let countries: Vec<String> = df.column("column_1").clone()
    .unwrap()
    .str()          
    .unwrap()
    .into_iter()     
    .map(|opt_val| opt_val.unwrap_or("unknown").to_string()) 
    .collect();
let root = BitMapBackend::new("gmm_5.png", (4000, 4000)).into_drawing_area();
root.fill(&WHITE).unwrap();
let mut chart = ChartBuilder::on(&root)
    .caption("GMM_5", ("sans-serif", 40))
    .margin(20)
    .build_cartesian_2d(-1000.0..1000.0, -1000.0..1000.0).unwrap();
chart.configure_mesh().draw().unwrap();
use std::f64::consts::PI;
let radius = 350.0;
for id in 0..countries.len(){
    for entry in std::fs::read_dir("Flags/").unwrap(){
        let file = entry.unwrap();
        let name = file.file_name().to_string_lossy().into_owned();
        if name.contains(&countries[id]){
            let img = image::open(file.path()).unwrap();
            let (width, height) = img.dimensions();
            let row = records.row(id);
            let rgb_img = img.to_rgb8();
            let real_id = clusters.targets()[id];
            let angle = (real_id as f64) * (2.0 * PI / n_clusters as f64);
            let offset_x = angle.cos() * radius;
            let offset_y = angle.sin() * radius;
            let pose = (row[0] * 100.0 + offset_x, row[1] * 100.0 + offset_y);
            let plt_img = BitMapElement::<(f64, f64), plotters::backend::RGBPixel>::with_ref(
                pose,
                rgb_img.dimensions(),
                rgb_img.as_raw()
            ).expect("pepes");
            
            chart.draw_series(std::iter::once(plt_img)).unwrap();
            break;
        }
    }
}
root.present().unwrap();
let img = image::open("gmm_5.png").expect("nfs");
let scaled = img.resize(1000, 1000, image::imageops::FilterType::Lanczos3);
scaled.save("gmm_5.png").expect("peps");
